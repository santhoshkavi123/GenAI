# %%
import os
import pickle
import yaml
import re
import itertools

# Decorators
from typing import List, Dict
from IPython.display import display, Markdown


# Change Directory
os.chdir("/Users/kavisanthoshkumar/Documents/GenerativeAIusingAWS/HR_Policy_QueryResolutionWithRAG")
with open('config.yaml', 'r') as file:
    config = yaml.safe_load(file)


# Create logging file
import logging 
logging.basicConfig(filename = config['logging']['logging_file_path'], 
                        filemode= 'w')

# Import langchain packages
from langchain_core.documents import Document
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.document_loaders import PyMuPDFLoader

# %%
# Create a logging instance
logger = logging.getLogger(__name__)
logger
# Out:
# <Logger __main__ (WARNING)>

# %% [markdown]
# ### 1. Read the PDF File

# %%
def DocumentViewer(hr_policy_docs:List[str], doc_page:int) -> None:
    print("=== Viewing: Page Content === \n")
    display(Markdown(hr_policy_docs[doc_page].page_content))
    print("=== Viewing: Metadata Information === \n")
    print( hr_policy_docs[doc_page].metadata)

# %%
input_file_path = config['inputs']['document_input_file_path']
loader = PyMuPDFLoader(
    file_path = input_file_path, 
    mode = 'page', 
    extract_images = False
)

hr_policy_documents = loader.load()
print(f"len of HR policy documents: {len(hr_policy_documents)}")
# Out:
# len of HR policy documents: 18

# %%
DocumentViewer(hr_policy_documents, 11)
# Out:
# === Viewing: Page Content ===
# 2.1.3 Gifts and Business Hospitality
# While the exchange of gifts and business hospitality may be common
# business practices, such activity can be misinterpreted or suggest the
# appearance of something improper, even when there is no improper intent.
# Avoid accepting or providing gifts and business hospitality to customers,
# suppliers, and business partners of the firm if it creates a perceived or actual
# conflict of interest or violates laws, regulations, or our firm's policies.
# Employees should never solicit, suggest, or request gifts or business
# hospitality in exchange for firm business or an unfair advantage.
# 2.1.4 Political Engagement
# We respect your right to engage in personal political activity. Your political
# activities are personal endeavors, but you must be mindful of potential
# impact to the firm's reputation. Your contributions and activities must be
# lawful, consistent with firm policies, and may not disrupt the firm or involve
# the use of firm time or resources (including staff, facilities, equipment,
# stationery, email, phones, supplies or mailing lists).
# You may not invite government officials or political figures to speak at or
# attend firm events unless you comply with our firm's policy requirements.
# Do not promise or imply firm sponsorship, contributions, or other support.
# You may not use firm funds to contribute to or make expenditures or
# election-related communications on behalf of candidates, political party
# committees or political action committees.
# Contents
# About
# Report
# 1.0 .. 3.0
# Closing
# 2.1.5 Personal Finances
# You must comply with all applicable laws, regulations and firm policies
# when managing your personal finances and investment activities. Our firm
# expects you to handle your personal finances responsibly and with
# integrity, and to base your personal investment decisions with long-term
# objectives in mind. You may not improperly use information you learned
# from work for your personal benefit. Investing in the business of a client or
# supplier with whom you have -or recently had -dealings with, in your
# role at the firm, can raise significant conflicts.
# In addition, the improper handling of your personal finances could
# undermine your credibility and the firm's or lead to increased regulatory
# scrutiny. Engaging in financial transactions (e.g., borrowing or other lending
# activities, joint investments, gambling, or betting - whether money is
# exchanged or not, etc.) with fellow employees, customers, suppliers is
# prohibited for these reasons.
# As an employee of a publicly traded company, you may have access to
# confidential or material, non-public information about our firm, clients and
# other companies that conduct or seek to do business with us. You must
# protect this information from unauthorized use, including from other
# employees who do not have a legitimate and continuous business need to
# access the information. Always use care when working away from the office
# and ensure your workspace provides proper privacy. Insider trading is
# illegal and strictly prohibited by firm policies. You must never use privileged
# or confidential information for personal gain or tell, ''tip", or share
# information you learned through work with others.
# Code of Conduct
# 9
# === Viewing: Metadata Information ===

# %%
with open('app/data/hr_policy_documents.pkl', 'rb') as file:
    hr_policy_documents = pickle.load(file)

print(f'length of the hr policy documents: {len(hr_policy_documents)}')
# Out:
# length of the hr policy documents: 18

# %%
DocumentViewer(hr_policy_documents, 15)
# Out:
# === Viewing: Page Content ===
# 3.1 A Dynamic and Thriving Workplace
# Nothing is more vital to the long-term growth of JPMorganChase than
# our ability to attract and retain talented and dedicated employees. You
# are our most valuable asset. Always treat each other, and our customers
# and suppliers, respectfully and fairly. Stay true to the principles
# embedded in our culture: honesty, integrity, accountability, diversity, and
# inclusion.
# We are committed to a working environment free of threats, intimidation,
# physical harm, and disruption. A non-violent, safe, and healthy workplace
# is critical to our well-being. We rely on you to promptly report any acts or
# threats of violence, or situations that could pose a threat to others. All
# workforce members are expected to comply with applicable laws and
# firm policies as they relate to the health, safety and security of our
# workforce, our customers, and others who may be present on our
# premises.
# Always conduct yourself appropriately when acting on behalf of our firm
# -both inside and outside of the office. Your conduct matters and can be
# perceived as a reflection of our firm's standards.
# 3.2 Diversity and Inclusion is a Priority
# A diverse network of people, a vibrant mix of cultures, a broad range of
# skills and experiences -we celebrate all the people of JPMorganChase
# around the world. A diversity of colleagues means diverse ideas and a
# more inclusive work experience. It also means that our workforce reflects
# the diverse set of customers we serve and helps us to address -and
# respond to -a wide variety of needs and opportunities in the
# marketplace.
# We prohibit discrimination, harassment, bias and prejudice in our
# workplace and against our workforce based on an individual's race, color,
# national origin or ancestry, ethnic origin, citizenship status, creed, religion,
# religious affiliation, age, sex, gender, pregnancy, maternity, paternity,
# caring responsibilities, marital status, relationship status, civil partnership,
# sexual orientation, transgender status, gender identity, gender expression,
# intersex status, genetic information, physical or mental disability or
# protected condition, military or veteran status, an individual having been a
# victim of domestic violence, sexual assault or abuse, an individual being
# the victim of a crime, any other community group protected under
# applicable law, or any other status protected under applicable local law.
# We do not tolerate discrimination, harassment, or inappropriate or abusive
# conduct by or against employees, customers, suppliers, contractors, or
# any other individuals who conduct business or seek to do business with
# our firm.
# We take all allegations of discrimination or harassment seriously. It is each
# employee's responsibility to report any concern or conduct that is or may
# be unlawful, abusive, or otherwise violates firm policies.
# Code of Conduct
# Contents
# About
# Report
# 1.0
# 2.0
# ..
# Closing
# 13
# === Viewing: Metadata Information ===
#
# {'producer': 'Adobe Acrobat Pro 2020 20 Paper Capture Plug-in with ClearScan', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-07-23T16:14:08-04:00', 'source': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'file_path': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'total_pages': 18, 'format': 'PDF 1.7', 'title': 'Our Code of Conduct 2024', 'author': 'JP Morgan Chase', 'subject': 'Code of Conduct', 'keywords': 'Our, Code, of, Conduct, 2024, JP, Morgan, Chase', 'moddate': '2024-08-05T10:50:00-04:00', 'trapped': '', 'modDate': "D:20240805105000-04'00'", 'creationDate': "D:20240723161408-04'00'", 'page': 15}

# %%
DocumentViewer(hr_policy_documents, 0)
# Out:
# === Viewing: Page Content ===
# Our Code
# of Conduct
# 2024
# JPMorgan Chase
# === Viewing: Metadata Information ===
#
# {'producer': 'Adobe Acrobat Pro 2020 20 Paper Capture Plug-in with ClearScan', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-07-23T16:14:08-04:00', 'source': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'file_path': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'total_pages': 18, 'format': 'PDF 1.7', 'title': 'Our Code of Conduct 2024', 'author': 'JP Morgan Chase', 'subject': 'Code of Conduct', 'keywords': 'Our, Code, of, Conduct, 2024, JP, Morgan, Chase', 'moddate': '2024-08-05T10:50:00-04:00', 'trapped': '', 'modDate': "D:20240805105000-04'00'", 'creationDate': "D:20240723161408-04'00'", 'page': 0}

# %%
DocumentViewer(hr_policy_documents, 1)
# Out:
# === Viewing: Page Content ===
# Code of Conduct
# JPMorganChase is deeply committed to being honest in all of our business dealings
# across the globe.
# The Code of Conduct represents our shared obligation to operate with the highest
# level of integrity and ethical conduct. We set high expectations and hold ourselves
# accountable. We do the right thing - not necessarily the easy or expedient thing. We
# abide by the letter and spirit of the laws and regulations everywhere we do business
# and have zero tolerance for unethical behavior. Personal accountability and
# ownership are priorities at our firm.
# Our Code of Conduct and firm policies are designed to encourage exceptional
# business relationships, enabling us to continually build on our proud heritage. We
# must always act with integrity and be responsible for our actions, show respect for
# each other as well as those with whom we do business.
# To support our firm's purpose of making dreams possible for everyone, everywhere,
# every day, we all must do our part to preserve the values that have made
# JPMorganChase the respected company it is today. That's why it's important to
# speak up when something doesn't seem right. If you encounter or suspect illegal or
# unethical conduct, report it immediately.
# Contents
# About
# Report
# 1.0
# 2.0
# 3.0
# Closing
# Remember, your actions matter.
# Jamie Dimon
# July2024
# Code of Conduct
# === Viewing: Metadata Information ===
#
# {'producer': 'Adobe Acrobat Pro 2020 20 Paper Capture Plug-in with ClearScan', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-07-23T16:14:08-04:00', 'source': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'file_path': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'total_pages': 18, 'format': 'PDF 1.7', 'title': 'Our Code of Conduct 2024', 'author': 'JP Morgan Chase', 'subject': 'Code of Conduct', 'keywords': 'Our, Code, of, Conduct, 2024, JP, Morgan, Chase', 'moddate': '2024-08-05T10:50:00-04:00', 'trapped': '', 'modDate': "D:20240805105000-04'00'", 'creationDate': "D:20240723161408-04'00'", 'page': 1}

# %%
DocumentViewer(hr_policy_documents, 2)
# Out:
# === Viewing: Page Content ===
# Table of Contents
# About this Document
# Report Potential Violation or Concern
# 2
# 3
# 1.0 Leading with Integrity
# 4
# 1.1 Our Ethics
# 4
# 1.2 Compliance with the law and Firm Policies
# 4
# 1.3 Personal Integrity and Ethical Decision Making
# 5
# -
# 1.3.1 Manager Responsibilities
# 5
# 1.4 Sharing Concerns
# 6
# -
# 1.4.1 Our Commitment to Non-Retaliation
# 2.0 A voiding Conflicts and Managing Information
# 7
# 2.1 Avoiding Conflicts of Interest
# 8
# 2.1.1 Outside Interests and External Activities
# 8
# 2.1.2 Personal Relationships
# 8
# 2.1.3 Gifts and Business Hospitality
# 9
# 2.1.4 Political Engagement
# 9
# 2.1.5 Personal Finances
# 9
# ..
# About
# Report
# 1.0
# 2.0
# 3.0
# Closing
# 2.2 Managing Information
# -
# 2.2.1 Communicating Responsibly
# -
# 2.2.2 Maintaining Data
# -
# 2.2.3 Using Firm Assets
# 3.0 Our Winning Culture
# 3.1 A Dynamic and Thriving Workplace
# 3.2 Diversity and Inclusion is a Priority
# Closing Thoughts
# 10
# 10
# 11
# 11
# 12
# 13
# 13
# 14
# Code of Conduct
# 1
# -
# -
# -
# -
# -
# === Viewing: Metadata Information ===
#
# {'producer': 'Adobe Acrobat Pro 2020 20 Paper Capture Plug-in with ClearScan', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-07-23T16:14:08-04:00', 'source': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'file_path': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'total_pages': 18, 'format': 'PDF 1.7', 'title': 'Our Code of Conduct 2024', 'author': 'JP Morgan Chase', 'subject': 'Code of Conduct', 'keywords': 'Our, Code, of, Conduct, 2024, JP, Morgan, Chase', 'moddate': '2024-08-05T10:50:00-04:00', 'trapped': '', 'modDate': "D:20240805105000-04'00'", 'creationDate': "D:20240723161408-04'00'", 'page': 2}

# %%
DocumentViewer(hr_policy_documents, 6)
# Out:
# === Viewing: Page Content ===
# 1.1 Our Ethics
# JPMorganChase is committed to ensuring employees act with honesty
# and integrity, treat customers fairly, and exercise sound judgment. This
# means doing the right thing, and speaking up, at all times, even when it is
# not easy or expedient. Our commitment to ethical business practices
# preserves our firm's reputation and creates a safe, healthy, productive, and
# collaborative work environment.
# Personal accountability and ownership are priorities at our firm. We expect
# you to hold yourself to the highest standards of ethical conduct. Always
# conduct yourself appropriately when acting on behalf of our firm - both
# inside and outside of the workplace. Your actions should reflect the firm's
# culture of integrity, respect, and inclusivity.
# 1.2 Compliance with the Law and Firm Policies
# The financial industry is highly regulated. Being aware of and complying
# with the laws and regulations under which we operate is not just a critical
# part of our business, but fundamental to who we are. It is important to
# comply with the letter, spirit, and intent of laws, regulations, and firm
# policies. Violating the law or engaging in unfair, deceptive, and abusive
# acts or practices may weaken customer confidence, put our reputation at
# risk, impact market integrity, or result in regulator criticism, legal action,
# fines or penalties, or other negative repercussions.
# You are expected to know and comply with the laws, regulations and firm
# policies that apply to you. Always follow the Code. If your business unit
# adopts policies that are more specific than the Code, you must follow
# those policies. In the event of a conflict with any provision of the Code and
# local law, you should always follow the law.
# Contents
# About
# Report
# ..
# 2.0
# 3.0
# Closing
# 1.3 Personal Integrity and Ethical Decision Making
# The Code will help guide you in making ethical decisions, but you won't
# find the answer to every possible situation. In the absence of a specific
# policy or procedure, you have a responsibility to use good judgment,
# comply with the spirit and the intent of the Code, and seek help from your
# manager or Compliance Officer.
# Always deal fairly and in good faith with our customers, suppliers,
# competitors, business partners, regulators, and other employees. Never
# take unfair advantage of anyone through manipulation, concealment,
# abuse of privileged or confidential information, misrepresentation of
# material fact, or any other unfair dealings or practices.
# Our competitive advantage comes through our superior products and
# services, never through unethical or illegal business practices.
# JPMorganChase is committed to complying with both the laws and
# regulations that address market integrity. Be mindful of sharing
# information and your interactions with competitors. Refrain from any
# action that may prevent, restrict, or alter fair competition. Do not
# compromise our firm's reputation or your own by engaging or appearing
# to engage in any form of corruption or misconduct. Never give, offer,
# promise, solicit, or accept anything of value - whether directly or indirectly
# through others such as third-party intermediaries - if it is intended or
# could be perceived as intended to improperly influence decisions on
# behalf of our firm. Be alert and escalate activities that are designed to
# hinder or prevent the detection of improper or illegal activity (e.g., money
# laundering, tax evasion, bribery, etc.).
# Take ownership - anticipate, identify, and manage the risk and impacts of
# the decisions and actions you take at work. You are in charge of your
# decisions. No one has the authority to tell you to do something unethical
# or illegal.
# Code of Conduct
# 4
# === Viewing: Metadata Information ===
#
# {'producer': 'Adobe Acrobat Pro 2020 20 Paper Capture Plug-in with ClearScan', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-07-23T16:14:08-04:00', 'source': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'file_path': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'total_pages': 18, 'format': 'PDF 1.7', 'title': 'Our Code of Conduct 2024', 'author': 'JP Morgan Chase', 'subject': 'Code of Conduct', 'keywords': 'Our, Code, of, Conduct, 2024, JP, Morgan, Chase', 'moddate': '2024-08-05T10:50:00-04:00', 'trapped': '', 'modDate': "D:20240805105000-04'00'", 'creationDate': "D:20240723161408-04'00'", 'page': 6}

# %% [markdown]
# - Conclusion (Reading the PDF documents):
#
# 1. PyMuPDFLoader was successfully able to read the pdf documents
# 2. It was able to handle the styling of the pdf documents
# 3. Next, we observed multiple sections are in one document, possible solution is to break each of these documents into individual sections

# %% [markdown]
# ### 2. Chunking Strategy PDFs

# %%
# -- Actual documents start from the sixth document onwards and ends at sixteen page

def ChunkingStrategySectionBreaking(docs: List[Document], min_doc_len:int, doc_index:int) -> List[Document]:
    """
        Function : Performing the Chunking Strategy only on the selected Documents
        Arguments :
            min_doc_len : minimum number of character length should be there to be considered for the document
            doc_index : document index form the hr_policy_document
    """

    pattern = r"\n(?=\d+\.\d+)"
    section_docs = [
            section.strip() \
                for section in re.split(pattern, docs[doc_index].page_content)
            ]
    processed_docs = []
    for sg_doc in section_docs:
        if len(sg_doc) > min_doc_len:

            lg_document = Document(
                page_content = sg_doc, 
                metadata = docs[doc_index].metadata
            )

            processed_docs.append(lg_document) 

    return processed_docs

sample_docs = ChunkingStrategySectionBreaking(
    docs = hr_policy_documents, 
    min_doc_len = 40, 
    doc_index = 6
)

# %%
DocumentViewer(sample_docs, 0)
# Out:
# === Viewing: Page Content ===
# 1.1 Our Ethics
# JPMorganChase is committed to ensuring employees act with honesty
# and integrity, treat customers fairly, and exercise sound judgment. This
# means doing the right thing, and speaking up, at all times, even when it is
# not easy or expedient. Our commitment to ethical business practices
# preserves our firm's reputation and creates a safe, healthy, productive, and
# collaborative work environment.
# Personal accountability and ownership are priorities at our firm. We expect
# you to hold yourself to the highest standards of ethical conduct. Always
# conduct yourself appropriately when acting on behalf of our firm - both
# inside and outside of the workplace. Your actions should reflect the firm's
# culture of integrity, respect, and inclusivity.
# === Viewing: Metadata Information ===
#
# {'producer': 'Adobe Acrobat Pro 2020 20 Paper Capture Plug-in with ClearScan', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-07-23T16:14:08-04:00', 'source': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'file_path': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'total_pages': 18, 'format': 'PDF 1.7', 'title': 'Our Code of Conduct 2024', 'author': 'JP Morgan Chase', 'subject': 'Code of Conduct', 'keywords': 'Our, Code, of, Conduct, 2024, JP, Morgan, Chase', 'moddate': '2024-08-05T10:50:00-04:00', 'trapped': '', 'modDate': "D:20240805105000-04'00'", 'creationDate': "D:20240723161408-04'00'", 'page': 6}

# %%
DocumentViewer(sample_docs, 1)
# Out:
# === Viewing: Page Content ===
# 1.2 Compliance with the Law and Firm Policies
# The financial industry is highly regulated. Being aware of and complying
# with the laws and regulations under which we operate is not just a critical
# part of our business, but fundamental to who we are. It is important to
# comply with the letter, spirit, and intent of laws, regulations, and firm
# policies. Violating the law or engaging in unfair, deceptive, and abusive
# acts or practices may weaken customer confidence, put our reputation at
# risk, impact market integrity, or result in regulator criticism, legal action,
# fines or penalties, or other negative repercussions.
# You are expected to know and comply with the laws, regulations and firm
# policies that apply to you. Always follow the Code. If your business unit
# adopts policies that are more specific than the Code, you must follow
# those policies. In the event of a conflict with any provision of the Code and
# local law, you should always follow the law.
# Contents
# About
# Report
# ..
# === Viewing: Metadata Information ===
#
# {'producer': 'Adobe Acrobat Pro 2020 20 Paper Capture Plug-in with ClearScan', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-07-23T16:14:08-04:00', 'source': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'file_path': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'total_pages': 18, 'format': 'PDF 1.7', 'title': 'Our Code of Conduct 2024', 'author': 'JP Morgan Chase', 'subject': 'Code of Conduct', 'keywords': 'Our, Code, of, Conduct, 2024, JP, Morgan, Chase', 'moddate': '2024-08-05T10:50:00-04:00', 'trapped': '', 'modDate': "D:20240805105000-04'00'", 'creationDate': "D:20240723161408-04'00'", 'page': 6}

# %%
DocumentViewer(sample_docs, 2)
# Out:
# === Viewing: Page Content ===
# 1.3 Personal Integrity and Ethical Decision Making
# The Code will help guide you in making ethical decisions, but you won't
# find the answer to every possible situation. In the absence of a specific
# policy or procedure, you have a responsibility to use good judgment,
# comply with the spirit and the intent of the Code, and seek help from your
# manager or Compliance Officer.
# Always deal fairly and in good faith with our customers, suppliers,
# competitors, business partners, regulators, and other employees. Never
# take unfair advantage of anyone through manipulation, concealment,
# abuse of privileged or confidential information, misrepresentation of
# material fact, or any other unfair dealings or practices.
# Our competitive advantage comes through our superior products and
# services, never through unethical or illegal business practices.
# JPMorganChase is committed to complying with both the laws and
# regulations that address market integrity. Be mindful of sharing
# information and your interactions with competitors. Refrain from any
# action that may prevent, restrict, or alter fair competition. Do not
# compromise our firm's reputation or your own by engaging or appearing
# to engage in any form of corruption or misconduct. Never give, offer,
# promise, solicit, or accept anything of value - whether directly or indirectly
# through others such as third-party intermediaries - if it is intended or
# could be perceived as intended to improperly influence decisions on
# behalf of our firm. Be alert and escalate activities that are designed to
# hinder or prevent the detection of improper or illegal activity (e.g., money
# laundering, tax evasion, bribery, etc.).
# Take ownership - anticipate, identify, and manage the risk and impacts of
# the decisions and actions you take at work. You are in charge of your
# decisions. No one has the authority to tell you to do something unethical
# or illegal.
# Code of Conduct
# 4
# === Viewing: Metadata Information ===
#
# {'producer': 'Adobe Acrobat Pro 2020 20 Paper Capture Plug-in with ClearScan', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-07-23T16:14:08-04:00', 'source': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'file_path': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'total_pages': 18, 'format': 'PDF 1.7', 'title': 'Our Code of Conduct 2024', 'author': 'JP Morgan Chase', 'subject': 'Code of Conduct', 'keywords': 'Our, Code, of, Conduct, 2024, JP, Morgan, Chase', 'moddate': '2024-08-05T10:50:00-04:00', 'trapped': '', 'modDate': "D:20240805105000-04'00'", 'creationDate': "D:20240723161408-04'00'", 'page': 6}

# %%
# Let's apply the function across all the documents 
hr_policy_chunked_documents = list(itertools.chain.from_iterable([ChunkingStrategySectionBreaking(
                            docs = hr_policy_documents, 
                            min_doc_len = 40, 
                            doc_index = index
                        ) for index in range(6, 17)]))

# %%
hr_policy_chunked_documents = [hr_policy_documents[4]] + hr_policy_chunked_documents
print(f"len of the hr_policy_chunked_documents: {len(hr_policy_chunked_documents)}")
# Out:
# len of the hr_policy_chunked_documents: 22

# %%
hr_policy_chunked_documents
# Out:
# [Document(metadata={'producer': 'Adobe Acrobat Pro 2020 20 Paper Capture Plug-in with ClearScan', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-07-23T16:14:08-04:00', 'source': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'file_path': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'total_pages': 18, 'format': 'PDF 1.7', 'title': 'Our Code of Conduct 2024', 'author': 'JP Morgan Chase', 'subject': 'Code of Conduct', 'keywords': 'Our, Code, of, Conduct, 2024, JP, Morgan, Chase', 'moddate': '2024-08-05T10:50:00-04:00', 'trapped': '', 'modDate': "D:20240805105000-04'00'", 'creationDate': "D:20240723161408-04'00'", 'page': 4}, page_content='Report a Potential Violation or Concern \nEvery JPMorganChase employee has the right and the \nobligation to report actual and potential violations of our Code \nand firm policies, as well as laws and regulations that govern \nJPMorganChase business. \nThere are several ways to report a potential or actual violation \nor raise a concern. Reporting can be done anonymously, \nwhere permitted by law. Translation services are also available. \nJPMorganChase strictly prohibits intimidation or retaliation \nagainst anyone who shares a potential or actual violation of \nour Code of Conduct, in good faith, or assists with an \ninvestigation or inquiry. \nFor concerns that are specifically related to accounting, \ninternal controls, auditing matters or financial reporting \npractices, contact the JPMorganChase Conduct Hotline, or the \nOffice of the General Counsel of JPMorgan Chase & Co. at 383 \nMadison Avenue, New York, NY 10179. \nYou can report concerns to the JPMorganChase Conduct Hotline in \nthree ways: \n1 \nPhone \n1-855-JPMCODE (U.S. and Canada Only) \nAll others - click here \n2 \nOnline \nSubmit here \n3 \nMobile \nScan \nCode of Conduct \nContents \nAbout \n-\n1.0 \n2.0 \n3.0 \nClosing \n2'),
#  Document(metadata={'producer': 'Adobe Acrobat Pro 2020 20 Paper Capture Plug-in with ClearScan', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-07-23T16:14:08-04:00', 'source': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'file_path': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'total_pages': 18, 'format': 'PDF 1.7', 'title': 'Our Code of Conduct 2024', 'author': 'JP Morgan Chase', 'subject': 'Code of Conduct', 'keywords': 'Our, Code, of, Conduct, 2024, JP, Morgan, Chase', 'moddate': '2024-08-05T10:50:00-04:00', 'trapped': '', 'modDate': "D:20240805105000-04'00'", 'creationDate': "D:20240723161408-04'00'", 'page': 6}, page_content="1.1 Our Ethics \nJPMorganChase is committed to ensuring employees act with honesty \nand integrity, treat customers fairly, and exercise sound judgment. This \nmeans doing the right thing, and speaking up, at all times, even when it is \nnot easy or expedient. Our commitment to ethical business practices \npreserves our firm's reputation and creates a safe, healthy, productive, and \ncollaborative work environment. \nPersonal accountability and ownership are priorities at our firm. We expect \nyou to hold yourself to the highest standards of ethical conduct. Always \nconduct yourself appropriately when acting on behalf of our firm - both \ninside and outside of the workplace. Your actions should reflect the firm's \nculture of integrity, respect, and inclusivity."),
#  Document(metadata={'producer': 'Adobe Acrobat Pro 2020 20 Paper Capture Plug-in with ClearScan', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-07-23T16:14:08-04:00', 'source': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'file_path': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'total_pages': 18, 'format': 'PDF 1.7', 'title': 'Our Code of Conduct 2024', 'author': 'JP Morgan Chase', 'subject': 'Code of Conduct', 'keywords': 'Our, Code, of, Conduct, 2024, JP, Morgan, Chase', 'moddate': '2024-08-05T10:50:00-04:00', 'trapped': '', 'modDate': "D:20240805105000-04'00'", 'creationDate': "D:20240723161408-04'00'", 'page': 6}, page_content='1.2 Compliance with the Law and Firm Policies \nThe financial industry is highly regulated. Being aware of and complying \nwith the laws and regulations under which we operate is not just a critical \npart of our business, but fundamental to who we are. It is important to \ncomply with the letter, spirit, and intent of laws, regulations, and firm \npolicies. Violating the law or engaging in unfair, deceptive, and abusive \nacts or practices may weaken customer confidence, put our reputation at \nrisk, impact market integrity, or result in regulator criticism, legal action, \nfines or penalties, or other negative repercussions. \nYou are expected to know and comply with the laws, regulations and firm \npolicies that apply to you. Always follow the Code. If your business unit \nadopts policies that are more specific than the Code, you must follow \nthose policies. In the event of a conflict with any provision of the Code and \nlocal law, you should always follow the law. \nContents \nAbout \nReport \n..'),
#  Document(metadata={'producer': 'Adobe Acrobat Pro 2020 20 Paper Capture Plug-in with ClearScan', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-07-23T16:14:08-04:00', 'source': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'file_path': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'total_pages': 18, 'format': 'PDF 1.7', 'title': 'Our Code of Conduct 2024', 'author': 'JP Morgan Chase', 'subject': 'Code of Conduct', 'keywords': 'Our, Code, of, Conduct, 2024, JP, Morgan, Chase', 'moddate': '2024-08-05T10:50:00-04:00', 'trapped': '', 'modDate': "D:20240805105000-04'00'", 'creationDate': "D:20240723161408-04'00'", 'page': 6}, page_content="1.3 Personal Integrity and Ethical Decision Making \nThe Code will help guide you in making ethical decisions, but you won't \nfind the answer to every possible situation. In the absence of a specific \npolicy or procedure, you have a responsibility to use good judgment, \ncomply with the spirit and the intent of the Code, and seek help from your \nmanager or Compliance Officer. \nAlways deal fairly and in good faith with our customers, suppliers, \ncompetitors, business partners, regulators, and other employees. Never \ntake unfair advantage of anyone through manipulation, concealment, \nabuse of privileged or confidential information, misrepresentation of \nmaterial fact, or any other unfair dealings or practices. \nOur competitive advantage comes through our superior products and \nservices, never through unethical or illegal business practices. \nJPMorganChase is committed to complying with both the laws and \nregulations that address market integrity. Be mindful of sharing \ninformation and your interactions with competitors. Refrain from any \naction that may prevent, restrict, or alter fair competition. Do not \ncompromise our firm's reputation or your own by engaging or appearing \nto engage in any form of corruption or misconduct. Never give, offer, \npromise, solicit, or accept anything of value - whether directly or indirectly \nthrough others such as third-party intermediaries - if it is intended or \ncould be perceived as intended to improperly influence decisions on \nbehalf of our firm. Be alert and escalate activities that are designed to \nhinder or prevent the detection of improper or illegal activity (e.g., money \nlaundering, tax evasion, bribery, etc.). \nTake ownership - anticipate, identify, and manage the risk and impacts of \nthe decisions and actions you take at work. You are in charge of your \ndecisions. No one has the authority to tell you to do something unethical \nor illegal. \nCode of Conduct \n4"),
#  Document(metadata={'producer': 'Adobe Acrobat Pro 2020 20 Paper Capture Plug-in with ClearScan', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-07-23T16:14:08-04:00', 'source': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'file_path': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'total_pages': 18, 'format': 'PDF 1.7', 'title': 'Our Code of Conduct 2024', 'author': 'JP Morgan Chase', 'subject': 'Code of Conduct', 'keywords': 'Our, Code, of, Conduct, 2024, JP, Morgan, Chase', 'moddate': '2024-08-05T10:50:00-04:00', 'trapped': '', 'modDate': "D:20240805105000-04'00'", 'creationDate': "D:20240723161408-04'00'", 'page':

#  Document(metadata={'producer': 'Adobe Acrobat Pro 2020 20 Paper Capture Plug-in with ClearScan', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-07-23T16:14:08-04:00', 'source': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'file_path': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'total_pages': 18, 'format': 'PDF 1.7', 'title': 'Our Code of Conduct 2024', 'author': 'JP Morgan Chase', 'subject': 'Code of Conduct', 'keywords': 'Our, Code, of, Conduct, 2024, JP, Morgan, Chase', 'moddate': '2024-08-05T10:50:00-04:00', 'trapped': '', 'modDate': "D:20240805105000-04'00'", 'creationDate': "D:20240723161408-04'00'", 'page': 12}, page_content="2.2.1 Communicating Responsibly2.2.1 Communicating Responsibly\nJPMorganChase is committed to making sure communications about our firm \nand its business are accurate and made by employees who are authorized to \nspeak on our behalf. We also recognize our obligation to protect the \nconfidentiality of our business and customer information. \nBe alert to situations where you may be perceived as representing or \nspeaking on behalf of JPMorganChase. Making recommendations or referring \npeople or companies that do or have done business with our firm may be \nconsidered a firm endorsement, which is not allowed. Know the limits on your \nauthority to speak, sign, or otherwise act on behalf of our firm, and don't take \nany action that exceeds those limits. Remember to seek preclearance before \nspeaking about the firm's business or your role and responsibilities at the \nfirm, in any public forum or publication. \nThe firm respects your right to engage in social, professional, and political \ndialogue outside of work. You must use good judgment when making \npersonal statements in public, including on your personal social media \naccounts. Also use care in internal communications and be responsible with \nyour comments on intranet postings. \nNothing in the Code should be interpreted to prevent employees from \nengaging in activities that are protected under laws and regulations that allow \nemployees to discuss or disclose their personal compensation information. \nPrinciples in Practice \nI want to start a financial blog. I don't plan to disclose that I'm an employee. Is this \npermitted? \nYou may not opine on or provide information relating to our firm's business, your \nrole or job responsibilities in a public forum unless you are specifically authorized to \ndo so. This applies whether you identify yourself as an employee or blog on your \npersonal time. Your comments should not have an adverse impact on our firm. \nCode of Conduct \n10"),
#  Document(metadata={'producer': 'Adobe Acrobat Pro 2020 20 Paper Capture Plug-in with ClearScan', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-07-23T16:14:08-04:00', 'source': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'file_path': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'total_pages': 18, 'format': 'PDF 1.7', 'title': 'Our Code of Conduct 2024', 'author': 'JP Morgan Chase', 'subject': 'Code of Conduct', 'keywords': 'Our, Code, of, Conduct, 2024, JP, Morgan, Chase', 'moddate': '2024-08-05T10:50:00-04:00', 'trapped': '', 'modDate': "D:20240805105000-04'00'", 'creationDate': "D:20240723161408-04'00'", 'page': 13}, page_content="2.2.2 Maintaining Data \nCreating and maintaining accurate and complete data is essential for \nour ability to meet our business needs as well as legal and regulatory \nrequirements. Make sure any disclosure we make to the government, \nregulatory authorities and investors meet these standards. Never falsify \ndata. You are responsible for maintaining the integrity of firm data, and \ncomplying with all recordkeeping policies, controls, and procedures we \nhave in place. \nPrinciples in Practice \nI'm using an internal large language model to create content for a client meeting. \nSome of the output does not seem balanced. Can I use the output? \nReview the output to ensure it is correct prior to using it. You are responsible for the \naccuracy of information you create and share on behalf of the firm - whether the \ninformation is used internally, externally or developed using emerging technology. \nContents \nAbout \nReport"),
#  Document(metadata={'producer': 'Adobe Acrobat Pro 2020 20 Paper Capture Plug-in with ClearScan', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-07-23T16:14:08-04:00', 'source': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'file_path': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'total_pages': 18, 'format': 'PDF 1.7', 'title': 'Our Code of Conduct 2024', 'author': 'JP Morgan Chase', 'subject': 'Code of Conduct', 'keywords': 'Our, Code, of, Conduct, 2024, JP, Morgan, Chase', 'moddate': '2024-08-05T10:50:00-04:00', 'trapped': '', 'modDate': "D:20240805105000-04'00'", 'creationDate': "D:20240723161408-04'00'", 'page': 13}, page_content="2.2.3 Using Firm Assets \nOur assets are the resources we use to conduct firm business. Use firm assets \nfor legitimate firm business and appropriately safeguard them against cyber-\nrelated risk and attack, theft, loss, waste, or abuse. By protecting our assets, \nwe protect our competitive advantage in the marketplace. You also have a \nresponsibility to extend the same degree of care to assets entrusted to our \nfirm by others. It is essential that you respect and protect the firm's physical \nand intellectual property, as well as our customer's information. \nAvoid using JPMorganChase assets, including technology and information \nresources, for your personal activities. Personal use of our devices, \ntechnology and other assets should be kept to a minimum. Firm assets may \nnot be used for personal gain and should never interfere with your business \nobligations, burden firm assets, introduce additional risk to our firm, \nnegatively impact colleagues or customers, or disrupt business operations. \nCode of Conduct \n11"),
#  Document(metadata={'producer': 'Adobe Acrobat Pro 2020 20 Paper Capture Plug-in with ClearScan', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-07-23T16:14:08-04:00', 'source': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'file_path': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'total_pages': 18, 'format': 'PDF 1.7', 'title': 'Our Code of Conduct 2024', 'author': 'JP Morgan Chase', 'subject': 'Code of Conduct', 'keywords': 'Our, Code, of, Conduct, 2024, JP, Morgan, Chase', 'moddate': '2024-08-05T10:50:00-04:00', 'trapped': '', 'modDate': "D:20240805105000-04'00'", 'creationDate': "D:20240723161408-04'00'", 'page': 15}, page_content="3.1 A Dynamic and Thriving Workplace \nNothing is more vital to the long-term growth of JPMorganChase than \nour ability to attract and retain talented and dedicated employees. You \nare our most valuable asset. Always treat each other, and our customers \nand suppliers, respectfully and fairly. Stay true to the principles \nembedded in our culture: honesty, integrity, accountability, diversity, and \ninclusion. \nWe are committed to a working environment free of threats, intimidation, \nphysical harm, and disruption. A non-violent, safe, and healthy workplace \nis critical to our well-being. We rely on you to promptly report any acts or \nthreats of violence, or situations that could pose a threat to others. All \nworkforce members are expected to comply with applicable laws and \nfirm policies as they relate to the health, safety and security of our \nworkforce, our customers, and others who may be present on our \npremises. \nAlways conduct yourself appropriately when acting on behalf of our firm \n-both inside and outside of the office. Your conduct matters and can be \nperceived as a reflection of our firm's standards."),
#  Document(metadata={'producer': 'Adobe Acrobat Pro 2020 20 Paper Capture Plug-in with ClearScan', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-07-23T16:14:08-04:00', 'source': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'file_path': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'total_pages': 18, 'format': 'PDF 1.7', 'title': 'Our Code of Conduct 2024', 'author': 'JP Morgan Chase', 'subject': 'Code of Conduct', 'keywords': 'Our, Code, of, Conduct, 2024, JP, Morgan, Chase', 'moddate': '2024-08-05T10:50:00-04:00', 'trapped': '', 'modDate': "D:20240805105000-04'00'", 'creationDate': "D:20240723161408-04'00'", 'page': 15}, page_content="3.2 Diversity and Inclusion is a Priority \nA diverse network of people, a vibrant mix of cultures, a broad range of \nskills and experiences -we celebrate all the people of JPMorganChase \naround the world. A diversity of colleagues means diverse ideas and a \nmore inclusive work experience. It also means that our workforce reflects \nthe diverse set of customers we serve and helps us to address -and \nrespond to -a wide variety of needs and opportunities in the \nmarketplace. \nWe prohibit discrimination, harassment, bias and prejudice in our \nworkplace and against our workforce based on an individual's race, color, \nnational origin or ancestry, ethnic origin, citizenship status, creed, religion, \nreligious affiliation, age, sex, gender, pregnancy, maternity, paternity, \ncaring responsibilities, marital status, relationship status, civil partnership, \nsexual orientation, transgender status, gender identity, gender expression, \nintersex status, genetic information, physical or mental disability or \nprotected condition, military or veteran status, an individual having been a \nvictim of domestic violence, sexual assault or abuse, an individual being \nthe victim of a crime, any other community group protected under \napplicable law, or any other status protected under applicable local law. \nWe do not tolerate discrimination, harassment, or inappropriate or abusive \nconduct by or against employees, customers, suppliers, contractors, or \nany other individuals who conduct business or seek to do business with \nour firm. \nWe take all allegations of discrimination or harassment seriously. It is each \nemployee's responsibility to report any concern or conduct that is or may \nbe unlawful, abusive, or otherwise violates firm policies. \nCode of Conduct \nContents \nAbout \nReport"),
#  Document(metadata={'producer': 'Adobe Acrobat Pro 2020 20 Paper Capture Plug-in with ClearScan', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-07-23T16:14:08-04:00', 'source': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'file_path': 'app/input/jp-morgan-chase-code-of-conduct-policy.pdf', 'total_pages': 18, 'format': 'PDF 1.7', 'title': 'Our Code of Conduct 2024', 'author': 'JP Morgan Chase', 'subject': 'Code of Conduct', 'keywords': 'Our, Code, of, Conduct, 2024, JP, Morgan, Chase', 'moddate': '2024-08-05T10:50:00-04:00', 'trapped': '', 'modDate': "D:20240805105000-04'00'", 'creationDate': "D:20240723161408-04'00'", 'page': 16}, page_content='Closing Thoughts \nOur core values are at the heart of what we do. Managers set the \'\'tone from the \ntop" and remind employees that it is paramount for each of us to be culture \ncarriers. You must always maintain your personal integrity and never lower your \nstandards. Always provide first-class service in a first-class way. \nThe people, products and services, and dedication to integrity have made \nJPMorganChase one of the largest and most successful financial institutions in \nthe world. Just as we are a leader in the financial industry, we want to be known \nas a leader in ethics. \nOur collective commitment to being accountable, straightforward, and honest in \nall of our business dealings makes JPMorganChase a respected company. \nEncourage others to deal fairly with clients and suppliers, be good stewards of \nthe firm\'s resources and foster a diverse and inclusive work environment. \nRemember, it is your responsibility to report any violations you know about and \nthose you suspect. JPMorganChase doesn\'t tolerate retaliation against anyone \nwho raises an issue or concern in good faith. \nIf you have questions about the Code of Conduct or any firm policy, ask your \nmanager, Human Resources, or local Compliance Officer for guidance. \nOur continued success is based on your ability to always do the right thing. \nBe a leader and proud culture carrier. We depend on YOU! \nCode of Conduct \nContents \nAbout \nReport')]
